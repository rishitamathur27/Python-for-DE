# %% [markdown]
# ## Extraction and Transformation

# %%
# !pip install spotipy
# Out:
# ...
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/252.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/252.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/252.0 kB ? eta -:--:--
# ...

# %%
# With Spotipy we can get full access to all of the music data provided by the Spotify platform

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Used for authentication

client_credentials_manager = SpotifyClientCredentials(client_id="cdac07a5448f4baa9e3fe8bf5bc17854" , client_secret="a4058cf5f0c1492ea706834c7ca6c019")

# %%
# Creating an object to extract data from spotify API and use the data from the soptipy
# Used for authorization

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Extract data from the top 100 trending songs on Spotify

playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbNG2KDcFcKOF']

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
# The playlist_tracks method returns a paginated result with details of the tracks of a playlist. So, you need to iterate over all pages to get the full data.
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-05-24T10:34:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bef167d5462ff8e94b933ffd3f1a17eed0c47f20?cid=cdac07a5448f4baa9e3fe8bf5bc17854',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2024-05-24T10:34:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bef167d5462ff8e94b933ffd3f1a17eed0c47f20?cid=cdac07a5448f4baa9e3fe8bf5bc17854',
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
# To find total no. of albums from this playlist

len(data['items'])
# Out:
# 50

# %%
data['items'][0]
# Out:
# {'added_at': '2024-05-24T10:34:06Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bef167d5462ff8e94b933ffd3f1a17eed0c47f20?cid=cdac07a5448f4baa9e3fe8bf5bc17854',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
# Firstly extracting info of the track album

data['items'][0]['track']['album']['id']
# Out:
# '52TwRwdTUMtkpglbOE5IRz'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'MILLION DOLLAR BABY'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-04-26'

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
# ...

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 2

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/52TwRwdTUMtkpglbOE5IRz'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/52TwRwdTUMtkpglbOE5IRz'

# %%
# Now I need to package all these info together and convert it into a dataframe

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    print(album_name)

    # Convert this into dictionary so that we can create a dataframe out of it
    album_elements = {'album_id' : album_id, 'name': album_name, 'release_date' : album_release_date, 'total_tracks': album_total_tracks, 'url': album_url}
    print(album_elements)
# Out:
# MILLION DOLLAR BABY
# {'album_id': '52TwRwdTUMtkpglbOE5IRz', 'name': 'MILLION DOLLAR BABY', 'release_date': '2024-04-26', 'total_tracks': 2, 'url': 'https://open.spotify.com/album/52TwRwdTUMtkpglbOE5IRz'}
# HIT ME HARD AND SOFT
# {'album_id': '7aJuG4TFXa2hmE4z1yxc3n', 'name': 'HIT ME HARD AND SOFT', 'release_date': '2024-05-17', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'}
# Espresso
# {'album_id': '5quMTd5zeI9yW5UDua8wS4', 'name': 'Espresso', 'release_date': '2024-04-12', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'}
# Not Like Us
# {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ', 'name': 'Not Like Us', 'release_date': '2024-05-04', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'}
# HIT ME HARD AND SOFT
# ...

# %%
# Now I need to package all these info together and convert it into a dataframe and put it in a list format
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']

    # Convert this into dictionary so that we can create a dataframe out of it
    album_elements = {'album_id' : album_id, 'name': album_name, 'release_date' : album_release_date, 'total_tracks': album_total_tracks, 'url': album_url}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '52TwRwdTUMtkpglbOE5IRz',
#   'name': 'MILLION DOLLAR BABY',
#   'release_date': '2024-04-26',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/52TwRwdTUMtkpglbOE5IRz'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'name': 'Not Like Us',
#   'release_date': '2024-05-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
# ...

# %%
# Now, extracting info of the track artists
# Note: One song can have multiple artists
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WaFQSHVGZQJTbf0BdxdNo'},
#   'href': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo',
#   'id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'name': 'Tommy Richman',
#   'type': 'artist',
#   'uri': 'spotify:artist:1WaFQSHVGZQJTbf0BdxdNo'}]

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '1WaFQSHVGZQJTbf0BdxdNo'

# %%
data['items'][0]
# Out:
# {'added_at': '2024-05-24T10:34:06Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bef167d5462ff8e94b933ffd3f1a17eed0c47f20?cid=cdac07a5448f4baa9e3fe8bf5bc17854',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WaFQSHVGZQJTbf0BdxdNo'}, 'href': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo', 'id': '1WaFQSHVGZQJTbf0BdxdNo', 'name': 'Tommy Richman', 'type': 'artist', 'uri': 'spotify:artist:1WaFQSHVGZQJTbf0BdxdNo'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'}, 'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B', 'id': '74KM79TiuVKeVCqs8QtB0B', 'name': 'Sabrina Carpenter', 'type': 'artist', 'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}]
# ...

# %%
# To get dictionary instead of list
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1WaFQSHVGZQJTbf0BdxdNo'}, 'href': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo', 'id': '1WaFQSHVGZQJTbf0BdxdNo', 'name': 'Tommy Richman', 'type': 'artist', 'uri': 'spotify:artist:1WaFQSHVGZQJTbf0BdxdNo'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'}, 'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B', 'id': '74KM79TiuVKeVCqs8QtB0B', 'name': 'Sabrina Carpenter', 'type': 'artist', 'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}
# ...

# %%
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                print(artist['id'])
# Out:
# 1WaFQSHVGZQJTbf0BdxdNo
# 6qqNVTkY8uBg9cP3Jd7DAH
# 74KM79TiuVKeVCqs8QtB0B
# 2YZyLoL8N0Wb9xBt1NhZWg
# 6qqNVTkY8uBg9cP3Jd7DAH
# 246dkjvS1zLTtiykXe5h60
# 4oUHIQIBe0LHzYfvXNW4QM
# 6qqNVTkY8uBg9cP3Jd7DAH
# 7CvTknweLr9feJtRGrpDBy
# 1Yj5Xey7kTwvZla8sqdsdE
# 0PCCGZ0wGLizHt2KZ7hhA2
# 3y2cIKLjiOlp1Np37WiUdH
# 2FXC3k01G6Gw61bmprjgqS
# 22wbnEMDvgVIAGdFeek6ET
# 06HL4z0CvFAxyc27GXpf02
# 246dkjvS1zLTtiykXe5h60
# 66CXWjxzNUsdJxJ2JdwvnR
# 6qqNVTkY8uBg9cP3Jd7DAH
# 6qqNVTkY8uBg9cP3Jd7DAH
# 6qqNVTkY8uBg9cP3Jd7DAH
# 5p9HO3XC5P3BLxJs5Mtrhm
# 6qqNVTkY8uBg9cP3Jd7DAH
# 6qqNVTkY8uBg9cP3Jd7DAH
# 33qOK5uJ8AR2xuQQAhHump
# 1fctva4kpRbg2k3v7kwRuS
# 1mcTU81TzQhprhouKaTkpq
# 3ZpEKRjHaHANcpk10u6Ntq
# 6qqNVTkY8uBg9cP3Jd7DAH
# 06HL4z0CvFAxyc27GXpf02
# 6qqNVTkY8uBg9cP3Jd7DAH
# 1Xyo4u8uXC1ZmMpatF05PJ
# 250b0Wlc5Vk0CoUsaCY84M
# 1pBLC0qVRTB5zVMuteQ9jJ
# 1RyvyyTE3xzB2ZywiAwp0i
# 0iEtIxbK0KxaSlF7G42ZOp
# 2YZyLoL8N0Wb9xBt1NhZWg
# 06HL4z0CvFAxyc27GXpf02
# 7tYKF4w9nC0nq9CsPZTHyP
# 2YZyLoL8N0Wb9xBt1NhZWg
# 11p2E654TTU8e0nZWBR4AL
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'artist_name': 'Tommy Richman',
#   'external_url': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element= {'song_id': song_id, 'song_name': song_name, 'duration_ms': song_duration, 'url': song_url, 'popularity': song_popularity, 
                   'song_added': song_added, 'album_id': album_id, 'artist_id': artist_id}

    song_list.append(song_element)

song_list
# Out:
# [{'song_id': '7fzHQizxTqy8wTXwlrgPQQ',
#   'song_name': 'MILLION DOLLAR BABY',
#   'duration_ms': 155151,
#   'url': 'https://open.spotify.com/track/7fzHQizxTqy8wTXwlrgPQQ',
#   'popularity': 99,
#   'song_added': '2024-05-24T10:34:06Z',
#   'album_id': '52TwRwdTUMtkpglbOE5IRz',
#   'artist_id': '1WaFQSHVGZQJTbf0BdxdNo'},
#  {'song_id': '629DixmZGHc7ILtEntuiWE',
#   'song_name': 'LUNCH',
#   'duration_ms': 179586,
#   'url': 'https://open.spotify.com/track/629DixmZGHc7ILtEntuiWE',
#   'popularity': 96,
#   'song_added': '2024-05-24T10:34:06Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '2qSkIjg1o9h3YT9RAgYN75',
#   'song_name': 'Espresso',
#   'duration_ms': 175459,
#   'url': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75',
#   'popularity': 100,
#   'song_added': '2024-05-24T10:34:06Z',
#   'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '6AI3ezQ4o3HUoP6Dhudph3',
# ...

# %%
import pandas as pd

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df.head(10)
# Out:
#                  album_id                           name release_date  \
# 0  1Mo4aZ8pdj6L1jx8zSwJnt  THE TORTURED POETS DEPARTMENT   2024-04-18
# 1  5quMTd5zeI9yW5UDua8wS4                       Espresso   2024-04-12
# 2  5HIWDdg3g9CTOtnevKDl1z     i like the way you kiss me   2024-03-19
# 3  5tSQtQGkrCJx3hoQxmLgfM                      Gata Only   2024-02-02
# 4  3P4SQqMMgjqfqVxgLwtYRk        Unreal Unearth: Unheard   2024-03-22
# 5  1Mo4aZ8pdj6L1jx8zSwJnt  THE TORTURED POETS DEPARTMENT   2024-04-18
# 6  168CdR21lfn0TTyw1Pkdcm       Fireworks & Rollerblades   2024-04-05
# 7  4JDXBZdRPId4devseaAOKH                         DECIDE   2022-09-16
# 8  5EYKrEDnKhhcNxGedaRQeK               eternal sunshine   2024-03-08
# 9  6egBeCLeGITzGSo5VyRjwZ             A Bar Song (Tipsy)   2024-04-12
#
#    total_tracks                                                url
# 0            16  https://open.spotify.com/album/1Mo4aZ8pdj6L1jx...
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
# Drop duplicates if any!

album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.head()
# Out:
#                  album_id                           name release_date  \
# 0  1Mo4aZ8pdj6L1jx8zSwJnt  THE TORTURED POETS DEPARTMENT   2024-04-18
# 1  5quMTd5zeI9yW5UDua8wS4                       Espresso   2024-04-12
# 2  5HIWDdg3g9CTOtnevKDl1z     i like the way you kiss me   2024-03-19
# 3  5tSQtQGkrCJx3hoQxmLgfM                      Gata Only   2024-02-02
# 4  3P4SQqMMgjqfqVxgLwtYRk        Unreal Unearth: Unheard   2024-03-22
#
#    total_tracks                                                url
# 0            16  https://open.spotify.com/album/1Mo4aZ8pdj6L1jx...
# 1             1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 2             1  https://open.spotify.com/album/5HIWDdg3g9CTOtn...
# 3             1  https://open.spotify.com/album/5tSQtQGkrCJx3ho...
# 4            20  https://open.spotify.com/album/3P4SQqMMgjqfqVx...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head(10)
# Out:
#                 artist_id        artist_name  \
# 0  06HL4z0CvFAxyc27GXpf02       Taylor Swift
# 1  246dkjvS1zLTtiykXe5h60        Post Malone
# 2  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 3  0PCCGZ0wGLizHt2KZ7hhA2            Artemas
# 4  7CvTknweLr9feJtRGrpDBy         FloyyMenor
# 5  1Yj5Xey7kTwvZla8sqdsdE            Cris Mj
# 6  2FXC3k01G6Gw61bmprjgqS             Hozier
# 7  06HL4z0CvFAxyc27GXpf02       Taylor Swift
# 8  22wbnEMDvgVIAGdFeek6ET       Benson Boone
# 9  5p9HO3XC5P3BLxJs5Mtrhm                Djo
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 1  https://api.spotify.com/v1/artists/246dkjvS1zL...
# 2  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 3  https://api.spotify.com/v1/artists/0PCCGZ0wGLi...
# 4  https://api.spotify.com/v1/artists/7CvTknweLr9...
# 5  https://api.spotify.com/v1/artists/1Yj5Xey7kTw...
# 6  https://api.spotify.com/v1/artists/2FXC3k01G6G...
# ...

# %%
# Drop duplicates if any!

artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id                      song_name  duration_ms  \
# 0  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)       228965
# 1  2qSkIjg1o9h3YT9RAgYN75                       Espresso       175459
# 2  2GxrNKugF82CnoRFbQfzPf     i like the way you kiss me       142514
# 3  6XjDF6nds4DE2BBbagZol6                      Gata Only       222000
# 4  5Z0UnEtpLDQyYlWwgi8m9C                      Too Sweet       251424
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2OzhQlSqBEmt7hm...          95
# 1  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          97
# 2  https://open.spotify.com/track/2GxrNKugF82CnoR...         100
# 3  https://open.spotify.com/track/6XjDF6nds4DE2BB...          98
# 4  https://open.spotify.com/track/5Z0UnEtpLDQyYlW...          90
#
#              song_added                album_id               artist_id
# 0  2024-05-03T10:08:29Z  1Mo4aZ8pdj6L1jx8zSwJnt  06HL4z0CvFAxyc27GXpf02
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      35 non-null     object
#  1   name          35 non-null     object
#  2   release_date  35 non-null     datetime64[ns]
#  3   total_tracks  35 non-null     int64
#  4   url           35 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
song_df.head()
# Out:
#                   song_id                      song_name  duration_ms  \
# 0  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)       228965
# 1  2qSkIjg1o9h3YT9RAgYN75                       Espresso       175459
# 2  2GxrNKugF82CnoRFbQfzPf     i like the way you kiss me       142514
# 3  6XjDF6nds4DE2BBbagZol6                      Gata Only       222000
# 4  5Z0UnEtpLDQyYlWwgi8m9C                      Too Sweet       251424
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2OzhQlSqBEmt7hm...          95
# 1  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          97
# 2  https://open.spotify.com/track/2GxrNKugF82CnoR...         100
# 3  https://open.spotify.com/track/6XjDF6nds4DE2BB...          98
# 4  https://open.spotify.com/track/5Z0UnEtpLDQyYlW...          90
#
#                  song_added                album_id               artist_id
# 0 2024-05-03 10:08:29+00:00  1Mo4aZ8pdj6L1jx8zSwJnt  06HL4z0CvFAxyc27GXpf02
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %% [markdown]
# ## Deploy on cloud
